# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('gurgaon_properties_cleaned_v2.csv').drop_duplicates()

# %%
df.head()
# Out:
#   property_type                society      sector  price  price_per_sqft  \
# 0          flat   tata gurgaon gateway  sector 113   3.21         11825.0
# 1          flat     ambience creacions   sector 22   1.99         15546.0
# 2         house            independent   sector 43   4.50         39062.0
# 3          flat   shree vardhman flora   sector 90   0.65          6789.0
# 4          flat  ss radiance residency   sector 12   0.60          5660.0
#
#      area                                       areaWithType  bedRoom  \
# 0  2715.0             Super Built up area 2520(234.12 sq.m.)        3
# 1  1280.0  Super Built up area 1380(128.21 sq.m.)Built Up...        2
# 2  1152.0                        Plot area 128(107.02 sq.m.)       20
# 3   957.0  Super Built up area 1350(125.42 sq.m.)Built Up...        2
# 4  1060.0                    Carpet area: 1060 (98.48 sq.m.)        3
#
#    bathroom balcony  floorNum      facing   agePossession  \
# 0         3       3       9.0         NaN    New Property
# 1         2       2       9.0  North-East    New Property
# 2        20      3+       4.0        East  Relatively New
# 3         2       3       9.0  South-East  Relatively New
# 4         3       2       3.0  North-East  Relatively New
#
#    super_built_up_area  built_up_area  carpet_area  study room  servant room  \
# 0               2520.0            NaN          NaN           0             0
# 1               1380.0         1285.0       1280.0           0             0
# 2                  NaN            NaN          NaN           0             1
# 3               1350.0         1050.0        950.0           1             0
# 4                  NaN            NaN       1060.0           0             0
#
#    store room  pooja room  others  furnishing_type  luxury_score
# 0           0           0       0                1            49
# 1           0           0       0                1            49
# 2           0           0       0                2            22
# 3           0           0       0                1            67
# 4           0           0       0                1            44

# %% [markdown]
# ### property_type vs price

# %%
sns.barplot(x=df['property_type'], y=df['price'], estimator=np.median)
# Out:
# <Axes: xlabel='property_type', ylabel='price'>

# %%
sns.boxplot(x=df['property_type'], y=df['price'])
# Out:
# <Axes: xlabel='property_type', ylabel='price'>

# %% [markdown]
# ### property_type vs area

# %%
sns.barplot(x=df['property_type'], y=df['built_up_area'], estimator=np.median)
# Out:
# <Axes: xlabel='property_type', ylabel='built_up_area'>

# %%
sns.boxplot(x=df['property_type'], y=df['built_up_area'])
# Out:
# <Axes: xlabel='property_type', ylabel='built_up_area'>

# %%
# removing that crazy outlier
df = df[df['built_up_area'] != 737147]

# %%
sns.boxplot(x=df['property_type'], y=df['built_up_area'])
# Out:
# <Axes: xlabel='property_type', ylabel='built_up_area'>

# %% [markdown]
# ### property_type vs price_per_sqft

# %%
sns.barplot(x=df['property_type'], y=df['price_per_sqft'], estimator=np.median)
# Out:
# <Axes: xlabel='property_type', ylabel='price_per_sqft'>

# %%
sns.boxplot(x=df['property_type'], y=df['price_per_sqft'])
# Out:
# <Axes: xlabel='property_type', ylabel='price_per_sqft'>

# %%
# check outliers
df[df['price_per_sqft'] > 100000][['property_type','society','sector','price','price_per_sqft','area','areaWithType', 'super_built_up_area', 'built_up_area', 'carpet_area']]
# Out:
#      property_type                      society     sector  price  \
# 65           house                  independent  sector 28   4.50
# 312          house       dlf city plots phase 2  sector 25  10.50
# 417          house     unitech uniworld resorts  sector 33   9.50
# 557          house          huda plot sector 38  sector 38   4.30
# 586          house  unitech nirvana birch court  sector 50   7.10
# 587           flat           ambience caitriona  sector 24  14.00
# 949          house               uppal southend  sector 49   6.75
# 1410         house                        ansal  sector 43   1.85
# 1490         house                  independent  sector 57   8.00
# 1646         house       unitech deerwood chase  sector 50   8.45
# 1748         house                   ardee city  sector 52   5.50
# 1902         house                  independent  sector 12   6.00
# 2035         house         bhim nagar, sector 6   sector 6   0.85
# 2152         house                  independent  sector 24  10.00
# 2326         house                  independent  sector 55   1.45
# 2494         house         eros rosewood villas  sector 49   2.75
# 2504         house                dlf the grove  sector 54   5.70
# 2615         house                  independent  sector 12   3.50
# 2658         house            vatika india next  sector 82   7.00
# 2715         house           vipul tatvam villa  sector 48   7.25
# 3003         house       dlf city plots phase 2  sector 25  10.00
# 3033         house                  independent  sector 54   3.75
# 3035         house     unitech uniworld resorts  sector 33  10.00
# 3149         house       emaar the palm springs  sector 54  24.00
# 3267         house                  independent   sector 4   0.60
# 3328         house                  independent  sector 23   2.80
# 3552         house                  independent  sector 38   8.00
# 3718         house                    rk excelo  sector 12   0.60
# 3772         house                  independent  sector 17   3.50
#
#       price_per_sqft   area  \
# 65          125000.0  360.0
# 312         261194.0  402.0
# 417         173992.0  546.0
# 557         245398.0  175.0
# 586         283333.0  251.0
# 587         200000.0  700.0
# 949         290948.0  232.0
# 1410        308333.0   60.0
# 1490        266666.0  300.0
# 1646        235376.0  359.0
# 1748        183333.0  300.0
# 1902        315789.0  190.0
# 2035        126865.0   67.0
# 2152        229885.0  435.0
# 2326        241666.0   60.0
# 2494        178571.0  154.0
# 2504        211111.0  270.0
# 2615        133079.0  263.0
# 2658        194444.0  360.0
# 2715        201388.0  360.0
# 3003        400000.0  250.0
# 3033        234375.0  160.0
# 3035        181818.0  550.0
# 3149        600000.0  400.0
# 3267        105263.0   57.0
# 3328        161849.0  173.0
# 3552        230547.0  347.0
# 3718        120000.0   50.0
# 3772        218750.0  160.0
#
#                                            areaWithType  super_built_up_area  \
# 65                     Built Up area: 360 (33.45 sq.m.)                  NaN
# 312                          Plot area 402(37.35 sq.m.)                  NaN
# 417                          Plot area 546(50.73 sq.m.)                  NaN
# 557   Plot area 163(15.14 sq.m.)Built Up area: 145 s...                  NaN
# 586                           Plot area 240(22.3 sq.m.)                  NaN
# 587                    Built Up area: 700 (65.03 sq.m.)                  NaN
# 949                          Plot area 232(21.55 sq.m.)                  NaN
# 1410                           Plot area 60(5.57 sq.m.)                  NaN
# 1490                         Plot area 300(27.87 sq.m.)                  NaN
# 1646                         Plot area 359(33.35 sq.m.)                  NaN
# 1748                         Plot area 300(27.87 sq.m.)                  NaN
# 1902  Plot area 190(17.65 sq.m.)Carpet area: 1600 sq...                  NaN
# 2035                           Plot area 67(6.22 sq.m.)                  NaN
# 2152                     Carpet area: 435 (40.41 sq.m.)                  NaN
# 2326                           Plot area 60(5.57 sq.m.)                  NaN
# 2494  Plot area 154(14.31 sq.m.)Carpet area: 1650 sq...                  NaN
# 2504                   Built Up area: 270 (25.08 sq.m.)                  NaN
# 2615  Plot area 263(24.43 sq.m.)Built Up area: 4800 ...                  NaN
# 2658  Plot area 360(33.45 sq.m.)Built Up area: 3900 ...                  NaN
# 2715                         Plot area 360(33.45 sq.m.)                  NaN
# 3003                         Plot area 250(23.23 sq.m.)                  NaN
# 3033                         Plot area 160(14.86 sq.m.)                  NaN
# 3035                          Plot area 550(51.1 sq.m.)                  NaN
# 3149                         Plot area 400(37.16 sq.m.)                  NaN
# 3267                            Plot area 57(5.3 sq.m.)                  NaN
# 3328  Plot area 173(16.07 sq.m.)Built Up area: 160 s...                  NaN
# 3552  Built Up area: 347 (32.24 sq.m.)Carpet area: 2...                  NaN
# 3718  Plot area 50(4.65 sq.m.)Built Up area: 30 sq.f...                  NaN
# 3772                   Built Up area: 160 (14.86 sq.m.)                  NaN
#
#       built_up_area  carpet_area
# 65            360.0          NaN
# 312             NaN          NaN
# 417             NaN          NaN
# 557           145.0          NaN
# 586             NaN          NaN
# 587           700.0          NaN
# 949             NaN          NaN
# 1410            NaN          NaN
# 1490            NaN          NaN
# 1646            NaN          NaN
# 1748            NaN          NaN
# 1902            NaN       1600.0
# 2035            NaN          NaN
# 2152            NaN        435.0
# 2326            NaN          NaN
# 2494            NaN       1650.0
# 2504          270.0          NaN
# 2615         4800.0       4400.0
# 2658         3900.0       3743.0
# 2715            NaN          NaN
# 3003            NaN          NaN
# 3033            NaN          NaN
# 3035            NaN          NaN
# 3149            NaN          NaN
# 3267            NaN          NaN
# 3328          160.0        150.0
# 3552          347.0        215.0
# 3718           30.0         15.0
# 3772          160.0          NaN

# %%
df.head()
# Out:
#   property_type                society      sector  price  price_per_sqft  \
# 0          flat   tata gurgaon gateway  sector 113   3.21         11825.0
# 1          flat     ambience creacions   sector 22   1.99         15546.0
# 2         house            independent   sector 43   4.50         39062.0
# 3          flat   shree vardhman flora   sector 90   0.65          6789.0
# 4          flat  ss radiance residency   sector 12   0.60          5660.0
#
#      area                                       areaWithType  bedRoom  \
# 0  2715.0             Super Built up area 2520(234.12 sq.m.)        3
# 1  1280.0  Super Built up area 1380(128.21 sq.m.)Built Up...        2
# 2  1152.0                        Plot area 128(107.02 sq.m.)       20
# 3   957.0  Super Built up area 1350(125.42 sq.m.)Built Up...        2
# 4  1060.0                    Carpet area: 1060 (98.48 sq.m.)        3
#
#    bathroom balcony  floorNum      facing   agePossession  \
# 0         3       3       9.0         NaN    New Property
# 1         2       2       9.0  North-East    New Property
# 2        20      3+       4.0        East  Relatively New
# 3         2       3       9.0  South-East  Relatively New
# 4         3       2       3.0  North-East  Relatively New
#
#    super_built_up_area  built_up_area  carpet_area  study room  servant room  \
# 0               2520.0            NaN          NaN           0             0
# 1               1380.0         1285.0       1280.0           0             0
# 2                  NaN            NaN          NaN           0             1
# 3               1350.0         1050.0        950.0           1             0
# 4                  NaN            NaN       1060.0           0             0
#
#    store room  pooja room  others  furnishing_type  luxury_score
# 0           0           0       0                1            49
# 1           0           0       0                1            49
# 2           0           0       0                2            22
# 3           0           0       0                1            67
# 4           0           0       0                1            44

# %%
sns.heatmap(pd.crosstab(df['property_type'],df['bedRoom']))
# Out:
# <Axes: xlabel='bedRoom', ylabel='property_type'>

# %%
# checking outliers
df[df['bedRoom'] >= 10]
# Out:
#      property_type                      society     sector  price  \
# 2            house                  independent  sector 43   4.50
# 39           house                  independent  sector 13   1.50
# 170          house  independent house sector 45  sector 40   9.00
# 328          house                 malibu towne  sector 47   8.50
# 335          house                  independent  sector 14   8.00
# ...            ...                          ...        ...    ...
# 3526         house                  independent  sector 25    NaN
# 3552         house                  independent  sector 38   8.00
# 3654         house                  independent  sector 25  16.00
# 3682         house                  independent  sector 25   9.00
# 3785         house                  independent  sector 55   7.49
#
#       price_per_sqft    area  \
# 2            39062.0  1152.0
# 39           11538.0  1300.0
# 170          38022.0  2367.0
# 328          53125.0  1600.0
# 335          17707.0  4518.0
# ...              ...     ...
# 3526             NaN     NaN
# 3552        230547.0   347.0
# 3654         59259.0  2700.0
# 3682         28490.0  3159.0
# 3785         27741.0  2700.0
#
#                                            areaWithType  bedRoom  bathroom  \
# 2                           Plot area 128(107.02 sq.m.)       20        20
# 39                         Plot area 1300(120.77 sq.m.)       10         7
# 170   Plot area 2367(219.9 sq.m.)Built Up area: 9000...       12        12
# 328                  Built Up area: 1600 (148.64 sq.m.)       12        12
# 335                         Plot area 502(419.74 sq.m.)       12         4
# ...                                                 ...      ...       ...
# 3526  Plot area 250(209.03 sq.m.)Built Up area: 260 ...       12        12
# 3552  Built Up area: 347 (32.24 sq.m.)Carpet area: 2...       10        10
# 3654  Plot area 350(292.64 sq.m.)Built Up area: 325 ...       16        16
# 3682                        Plot area 351(293.48 sq.m.)       10        10
# 3785                        Plot area 300(250.84 sq.m.)       12        12
#
#      balcony  floorNum      facing   agePossession  super_built_up_area  \
# 2         3+       4.0        East  Relatively New                  NaN
# 39         3       4.0        East  Moderately Old                  NaN
# 170        3       4.0  North-West    New Property                  NaN
# 328       3+       4.0       North    New Property                  NaN
# 335       3+       3.0       North    Old Property                  NaN
# ...      ...       ...         ...             ...                  ...
# 3526      3+       4.0  North-East    New Property                  NaN
# 3552      3+       1.0       North       Undefined                  NaN
# 3654      3+       4.0        West    New Property                  NaN
# 3682       3       3.0        East    Old Property                  NaN
# 3785      3+       4.0  South-East  Relatively New                  NaN
#
#       built_up_area  carpet_area  study room  servant room  store room  \
# 2               NaN          NaN           0             1           0
# 39              NaN          NaN           0             0           0
# 170          9000.0       6000.0           0             1           0
# 328          1600.0          NaN           0             0           0
# 335             NaN          NaN           0             1           1
# ...             ...          ...         ...           ...         ...
# 3526          260.0        245.0           1             1           0
# 3552          347.0        215.0           0             0           0
# 3654          325.0        300.0           1             1           1
# 3682            NaN          NaN           0             0           0
# 3785            NaN          NaN           1             1           0
#
#       pooja room  others  furnishing_type  luxury_score
# 2              0       0                2            22
# 39             0       0                1             0
# 170            0       0                0            71
# 328            0       0                0            99
# 335            0       0                1            32
# ...          ...     ...              ...           ...
# 3526           1       1                2           144
# 3552           0       0                1             0
# 3654           1       0                0            72
# 3682           1       0                0            64
# 3785           1       0                0            49
#
# [72 rows x 23 columns]

# %%
sns.barplot(x=df['property_type'],y=df['floorNum'])
# Out:
# <Axes: xlabel='property_type', ylabel='floorNum'>

# %%
sns.boxplot(x=df['property_type'],y=df['floorNum'])
# Out:
# <Axes: xlabel='property_type', ylabel='floorNum'>

# %%
# checking for outliers
df[(df['property_type'] == 'house') & (df['floorNum'] > 10)]
# Out:
#      property_type                  society      sector  price  \
# 53           house               ninex city   sector 76   1.75
# 274          house              spaze privy   sector 72   3.10
# 385          house              independent   sector 92   1.80
# 446          house  indiabulls centrum park  sector 103   3.25
# 517          house          godrej meridien  sector 106   5.60
# 1036         house              greenopolis   sector 89   0.70
# 1467         house      satya the hermitage  sector 103   3.15
# 1825         house           dlf the arbour   sector 63   8.50
# 1852         house              spaze privy   sector 72   3.09
# 2086         house      ireo victory valley   sector 67   8.00
# 2409         house        suncity avenue 76   sector 76   0.75
# 2459         house         suncity township   sector 54   2.00
# 3424         house           ats tourmaline  sector 109   1.87
# 3611         house   vatika the seven lamps   sector 82   1.60
#
#       price_per_sqft    area  \
# 53            6250.0  2800.0
# 274           8486.0  3653.0
# 385           7627.0  2360.0
# 446           8125.0  4000.0
# 517          14000.0  4000.0
# 1036          5397.0  1297.0
# 1467          6702.0  4700.0
# 1825         21519.0  3950.0
# 1852          6981.0  4426.0
# 2086         22222.0  3600.0
# 2409         10067.0   745.0
# 2459         30968.0   646.0
# 3424          8697.0  2150.0
# 3611          6597.0  2425.0
#
#                                            areaWithType  bedRoom  bathroom  \
# 53                     Carpet area: 2800 (260.13 sq.m.)        4         4
# 274                        Plot area 3653(339.37 sq.m.)        5         5
# 385                  Built Up area: 2360 (219.25 sq.m.)        4         5
# 446                        Plot area 4000(371.61 sq.m.)        4         3
# 517                        Plot area 4000(371.61 sq.m.)        5         4
# 1036                  Built Up area: 1297 (120.5 sq.m.)        2         2
# 1467                 Built Up area: 4700 (436.64 sq.m.)        4         5
# 1825                 Built Up area: 3950 (366.97 sq.m.)        4         4
# 1852  Built Up area: 3653 (339.37 sq.m.)Carpet area:...        5         5
# 2086                        Plot area 400(334.45 sq.m.)        6         7
# 2409  Plot area 745(69.21 sq.m.)Built Up area: 745 s...        2         2
# 2459  Plot area 60Built Up area: 60 sq.m.Carpet area...        9         9
# 3424                 Built Up area: 2150 (199.74 sq.m.)        3         4
# 3611                       Plot area 2425(225.29 sq.m.)        4         4
#
#      balcony  floorNum      facing       agePossession  super_built_up_area  \
# 53         0      14.0         NaN           Undefined                  NaN
# 274       3+      21.0         NaN      Relatively New                  NaN
# 385        0      13.0         NaN           Undefined                  NaN
# 446       3+      20.0         NaN  Under Construction                  NaN
# 517       3+      33.0  North-East        New Property                  NaN
# 1036       2      14.0  North-East           Undefined                  NaN
# 1467       0      12.0        East           Undefined                  NaN
# 1825      3+      27.0         NaN           Undefined                  NaN
# 1852      3+      14.0        East      Relatively New                  NaN
# 2086      3+      51.0  North-East      Moderately Old                  NaN
# 2409       2      11.0  North-East        New Property                  NaN
# 2459       3      11.0       North      Relatively New                  NaN
# 3424       0      12.0         NaN           Undefined                  NaN
# 3611      3+      16.0       North      Moderately Old                  NaN
#
#       built_up_area  carpet_area  study room  servant room  store room  \
# 53              NaN       2800.0           0             0           0
# 274             NaN          NaN           0             0           0
# 385          2360.0          NaN           0             0           0
# 446             NaN          NaN           0             0           0
# 517             NaN          NaN           1             1           1
# 1036         1297.0          NaN           0             0           0
# 1467         4700.0          NaN           0             0           0
# 1825         3950.0          NaN           0             0           0
# 1852         3653.0       2922.0           0             1           0
# 2086            NaN          NaN           1             1           0
# 2409          745.0          NaN           0             0           0
# 2459           60.0         59.0           0             1           0
# 3424         2150.0          NaN           0             0           0
# 3611            NaN          NaN           0             1           0
#
#       pooja room  others  furnishing_type  luxury_score
# 53             0       0                1             0
# 274            0       0                1             0
# 385            0       0                1             0
# 446            0       0                1            51
# 517            1       0                1           151
# 1036           0       0                1             0
# 1467           0       0                1            61
# 1825           0       0                1            61
# 1852           0       0                0            33
# 2086           1       0                0            49
# 2409           0       0                1            40
# 2459           0       0                2             7
# 3424           0       0                1             0
# 3611           0       0                1            94

# %%
# conclusion houses(villa) but in appartments

# %%
df.head()
# Out:
#   property_type                society      sector  price  price_per_sqft  \
# 0          flat   tata gurgaon gateway  sector 113   3.21         11825.0
# 1          flat     ambience creacions   sector 22   1.99         15546.0
# 2         house            independent   sector 43   4.50         39062.0
# 3          flat   shree vardhman flora   sector 90   0.65          6789.0
# 4          flat  ss radiance residency   sector 12   0.60          5660.0
#
#      area                                       areaWithType  bedRoom  \
# 0  2715.0             Super Built up area 2520(234.12 sq.m.)        3
# 1  1280.0  Super Built up area 1380(128.21 sq.m.)Built Up...        2
# 2  1152.0                        Plot area 128(107.02 sq.m.)       20
# 3   957.0  Super Built up area 1350(125.42 sq.m.)Built Up...        2
# 4  1060.0                    Carpet area: 1060 (98.48 sq.m.)        3
#
#    bathroom balcony  floorNum      facing   agePossession  \
# 0         3       3       9.0         NaN    New Property
# 1         2       2       9.0  North-East    New Property
# 2        20      3+       4.0        East  Relatively New
# 3         2       3       9.0  South-East  Relatively New
# 4         3       2       3.0  North-East  Relatively New
#
#    super_built_up_area  built_up_area  carpet_area  study room  servant room  \
# 0               2520.0            NaN          NaN           0             0
# 1               1380.0         1285.0       1280.0           0             0
# 2                  NaN            NaN          NaN           0             1
# 3               1350.0         1050.0        950.0           1             0
# 4                  NaN            NaN       1060.0           0             0
#
#    store room  pooja room  others  furnishing_type  luxury_score
# 0           0           0       0                1            49
# 1           0           0       0                1            49
# 2           0           0       0                2            22
# 3           0           0       0                1            67
# 4           0           0       0                1            44

# %%
sns.heatmap(pd.crosstab(df['property_type'],df['agePossession']))
# Out:
# <Axes: xlabel='agePossession', ylabel='property_type'>

# %%
sns.heatmap(pd.pivot_table(df,index='property_type',columns='agePossession',values='price',aggfunc='mean'),annot=True)
# Out:
# <Axes: xlabel='agePossession', ylabel='property_type'>

# %%
plt.figure(figsize=(15,4))
sns.heatmap(pd.pivot_table(df,index='property_type',columns='bedRoom',values='price',aggfunc='mean'),annot=True)
# Out:
# <Axes: xlabel='bedRoom', ylabel='property_type'>

# %%
sns.heatmap(pd.crosstab(df['property_type'],df['furnishing_type']))
# Out:
# <Axes: xlabel='furnishing_type', ylabel='property_type'>

# %%
sns.heatmap(pd.pivot_table(df,index='property_type',columns='furnishing_type',values='price',aggfunc='mean'),annot=True)
# Out:
# <Axes: xlabel='furnishing_type', ylabel='property_type'>

# %%
sns.barplot(x=df['property_type'],y=df['luxury_score'])
# Out:
# <Axes: xlabel='property_type', ylabel='luxury_score'>

# %%
sns.boxplot(x=df['property_type'],y=df['luxury_score'])
# Out:
# <Axes: xlabel='property_type', ylabel='luxury_score'>

# %%
df.head()
# Out:
#   property_type                society      sector  price  price_per_sqft  \
# 0          flat   tata gurgaon gateway  sector 113   3.21         11825.0
# 1          flat     ambience creacions   sector 22   1.99         15546.0
# 2         house            independent   sector 43   4.50         39062.0
# 3          flat   shree vardhman flora   sector 90   0.65          6789.0
# 4          flat  ss radiance residency   sector 12   0.60          5660.0
#
#      area                                       areaWithType  bedRoom  \
# 0  2715.0             Super Built up area 2520(234.12 sq.m.)        3
# 1  1280.0  Super Built up area 1380(128.21 sq.m.)Built Up...        2
# 2  1152.0                        Plot area 128(107.02 sq.m.)       20
# 3   957.0  Super Built up area 1350(125.42 sq.m.)Built Up...        2
# 4  1060.0                    Carpet area: 1060 (98.48 sq.m.)        3
#
#    bathroom balcony  floorNum      facing   agePossession  \
# 0         3       3       9.0         NaN    New Property
# 1         2       2       9.0  North-East    New Property
# 2        20      3+       4.0        East  Relatively New
# 3         2       3       9.0  South-East  Relatively New
# 4         3       2       3.0  North-East  Relatively New
#
#    super_built_up_area  built_up_area  carpet_area  study room  servant room  \
# 0               2520.0            NaN          NaN           0             0
# 1               1380.0         1285.0       1280.0           0             0
# 2                  NaN            NaN          NaN           0             1
# 3               1350.0         1050.0        950.0           1             0
# 4                  NaN            NaN       1060.0           0             0
#
#    store room  pooja room  others  furnishing_type  luxury_score
# 0           0           0       0                1            49
# 1           0           0       0                1            49
# 2           0           0       0                2            22
# 3           0           0       0                1            67
# 4           0           0       0                1            44

# %%
# sector analysis
plt.figure(figsize=(15,6))
sns.heatmap(pd.crosstab(df['property_type'],df['sector'].sort_index()))
# Out:
# <Axes: xlabel='sector', ylabel='property_type'>

# %%
# sector analysis
import re
# Group by 'sector' and calculate the average price
avg_price_per_sector = df.groupby('sector')['price'].mean().reset_index()

# Function to extract sector numbers
def extract_sector_number(sector_name):
    match = re.search(r'\d+', sector_name)
    if match:
        return int(match.group())
    else:
        return float('inf')  # Return a large number for non-numbered sectors

avg_price_per_sector['sector_number'] = avg_price_per_sector['sector'].apply(extract_sector_number)

# Sort by sector number
avg_price_per_sector_sorted_by_sector = avg_price_per_sector.sort_values(by='sector_number')

# Plot the heatmap
plt.figure(figsize=(5, 25))
sns.heatmap(avg_price_per_sector_sorted_by_sector.set_index('sector')[['price']], annot=True, fmt=".2f", linewidths=.5)
plt.title('Average Price per Sector (Sorted by Sector Number)')
plt.xlabel('Average Price')
plt.ylabel('Sector')
plt.show()

# %%
avg_price_per_sqft_sector = df.groupby('sector')['price_per_sqft'].mean().reset_index()

avg_price_per_sqft_sector['sector_number'] = avg_price_per_sqft_sector['sector'].apply(extract_sector_number)

# Sort by sector number
avg_price_per_sqft_sector_sorted_by_sector = avg_price_per_sqft_sector.sort_values(by='sector_number')

# Plot the heatmap
plt.figure(figsize=(5, 25))
sns.heatmap(avg_price_per_sqft_sector_sorted_by_sector.set_index('sector')[['price_per_sqft']], annot=True, fmt=".2f", linewidths=.5)
plt.title('Sector (Sorted by Sector Number)')
plt.xlabel('Average Price per sqft')
plt.ylabel('Sector')
plt.show()

# %%
luxury_score = df.groupby('sector')['luxury_score'].mean().reset_index()

luxury_score['sector_number'] = luxury_score['sector'].apply(extract_sector_number)

# Sort by sector number
luxury_score_sector = luxury_score.sort_values(by='sector_number')

# Plot the heatmap
plt.figure(figsize=(5, 25))
sns.heatmap(luxury_score_sector.set_index('sector')[['luxury_score']], annot=True, fmt=".2f", linewidths=.5)
plt.title('Sector (Sorted by Sector Number)')
plt.xlabel('Average Price per sqft')
plt.ylabel('Sector')
plt.show()

# %%
df.head()
# Out:
#   property_type                society      sector  price  price_per_sqft  \
# 0          flat   tata gurgaon gateway  sector 113   3.21         11825.0
# 1          flat     ambience creacions   sector 22   1.99         15546.0
# 2         house            independent   sector 43   4.50         39062.0
# 3          flat   shree vardhman flora   sector 90   0.65          6789.0
# 4          flat  ss radiance residency   sector 12   0.60          5660.0
#
#      area                                       areaWithType  bedRoom  \
# 0  2715.0             Super Built up area 2520(234.12 sq.m.)        3
# 1  1280.0  Super Built up area 1380(128.21 sq.m.)Built Up...        2
# 2  1152.0                        Plot area 128(107.02 sq.m.)       20
# 3   957.0  Super Built up area 1350(125.42 sq.m.)Built Up...        2
# 4  1060.0                    Carpet area: 1060 (98.48 sq.m.)        3
#
#    bathroom balcony  floorNum      facing   agePossession  \
# 0         3       3       9.0         NaN    New Property
# 1         2       2       9.0  North-East    New Property
# 2        20      3+       4.0        East  Relatively New
# 3         2       3       9.0  South-East  Relatively New
# 4         3       2       3.0  North-East  Relatively New
#
#    super_built_up_area  built_up_area  carpet_area  study room  servant room  \
# 0               2520.0            NaN          NaN           0             0
# 1               1380.0         1285.0       1280.0           0             0
# 2                  NaN            NaN          NaN           0             1
# 3               1350.0         1050.0        950.0           1             0
# 4                  NaN            NaN       1060.0           0             0
#
#    store room  pooja room  others  furnishing_type  luxury_score
# 0           0           0       0                1            49
# 1           0           0       0                1            49
# 2           0           0       0                2            22
# 3           0           0       0                1            67
# 4           0           0       0                1            44

# %% [markdown]
# ### price

# %%
plt.figure(figsize=(12, 8))
sns.scatterplot(
    data=df[df['area'] < 10000],
    x='area',
    y='price',
    hue='bedRoom'
)
plt.show()

# %%
plt.figure(figsize=(12, 8))
sns.scatterplot(
    data=df[df['area'] < 10000],
    x='area',
    y='price',
    hue='agePossession'
)
plt.show()

# %%
plt.figure(figsize=(12, 8))
sns.scatterplot(
    data=df[df['area'] < 10000],
    x='area',
    y='price',
    hue=df[df['area'] < 10000]['furnishing_type'].astype('category')
)
plt.show()

# %%
sns.barplot(x=df['bedRoom'],y=df['price'],estimator=np.median)
# Out:
# <Axes: xlabel='bedRoom', ylabel='price'>

# %%
sns.barplot(x=df['agePossession'],y=df['price'],estimator=np.median)
plt.xticks(rotation='vertical')
plt.show()

# %%
sns.barplot(x=df['agePossession'],y=df['area'],estimator=np.median)
plt.xticks(rotation='vertical')
plt.show()

# %%
sns.barplot(x=df['furnishing_type'],y=df['price'],estimator=np.median)
# Out:
# <Axes: xlabel='furnishing_type', ylabel='price'>

# %%
sns.scatterplot(x=df['luxury_score'], y=df['price'])
# Out:
# <Axes: xlabel='luxury_score', ylabel='price'>

# %% [markdown]
# ### correlation

# %%
sns.pairplot(df)
